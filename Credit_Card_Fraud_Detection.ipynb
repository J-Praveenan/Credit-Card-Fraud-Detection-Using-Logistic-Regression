# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading the dataset to a Pandas Data Frame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# Show first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
# Show last 5 rows of the dataset
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 196167  131385.0  0.117571  0.456780 -2.077266 -2.073220  0.408703 -2.275294
# 196168  131387.0  1.887546 -0.515073 -1.375326  0.219076  0.033817 -0.424882
# 196169  131387.0 -0.341639 -1.244251  0.390240 -1.127744 -0.489407 -0.679562
# 196170  131388.0  2.066743  0.256342 -2.145649  0.915330  1.063709 -0.432069
# 196171  131388.0 -0.180122  0.935909 -0.355988 -0.597037  0.614762 -0.793247
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 196167  0.894539 -0.122748 -1.222025  ...  0.698561  1.971647 -0.063868
# 196168  0.109803 -0.223258  1.031596  ...  0.132409  0.514453 -0.024536
# 196169  0.250800  0.053157  1.704313  ...  0.149890  0.255464  1.045243
# 196170  0.584642 -0.194476 -0.273594  ...  0.131980  0.399313 -0.027681
# 196171  0.902214 -0.077185  0.086829  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 196167  0.085824 -1.041937 -0.126021  0.381036  0.293188     5.0    0.0
# 196168  0.686896  0.211164  0.159660 -0.040507 -0.040356    93.3    0.0
# 196169 -0.018635 -2.361446  0.037110  0.278248  0.389531   200.0    0.0
# 196170  0.197329  0.482546 -0.501574 -0.042849 -0.073935     1.5    0.0
# 196171       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# Display the Information of the data set
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196172 entries, 0 to 196171
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    196172 non-null  float64
#  1   V1      196172 non-null  float64
#  2   V2      196172 non-null  float64
#  3   V3      196172 non-null  float64
#  4   V4      196172 non-null  float64
#  5   V5      196172 non-null  float64
#  6   V6      196172 non-null  float64
#  7   V7      196172 non-null  float64
#  8   V8      196172 non-null  float64
#  9   V9      196172 non-null  float64
#  10  V10     196172 non-null  float64
#  11  V11     196172 non-null  float64
#  12  V12     196172 non-null  float64
#  13  V13     196172 non-null  float64
#  14  V14     196172 non-null  float64
#  15  V15     196172 non-null  float64
#  16  V16     196172 non-null  float64
#  17  V17     196172 non-null  float64
#  18  V18     196172 non-null  float64
#  19  V19     196172 non-null  float64
#  20  V20     196171 non-null  float64
#  21  V21     196171 non-null  float64
#  22  V22     196171 non-null  float64
#  23  V23     196171 non-null  float64
#  24  V24     196171 non-null  float64
#  25  V25     196171 non-null  float64
#  26  V26     196171 non-null  float64
#  27  V27     196171 non-null  float64
#  28  V28     196171 non-null  float64
#  29  Amount  196171 non-null  float64
#  30  Class   196171 non-null  float64
# dtypes: float64(31)
# memory usage: 46.4 MB

# %%
# Checking the number of missing values
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# Dropping the missing values
# because least number of missing vlaues such as count is 1
credit_card_data = credit_card_data.dropna()

# %%
# Re-Checking the number of missing values
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Change the data type of the Class attribute float to int
credit_card_data['Class'] = credit_card_data['Class'].astype(int)

# %%
# Distribution of legit and fraudulent transaction
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    195789
# 1       382
# Name: count, dtype: int64

# %% [markdown]
# This dataset is highly unblanced
#
# 0 --> Normal Transaction <br>
# 1 --> Fraudulent Transaction

# %%
# Seperating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (195789, 31)
# (382, 31)

# %%
# Statistical measures of the data
legit.Amount.describe()
# Out:
# count    195789.000000
# mean         89.582366
# std         248.816252
# min           0.000000
# 25%           5.990000
# 50%          22.950000
# 75%          79.000000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     382.000000
# mean      118.009607
# std       248.655921
# min         0.000000
# 25%         1.000000
# 50%        11.855000
# 75%       104.030000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      69456.834689 -0.100902 -0.002688  0.353456  0.072217 -0.110722
# 1      60726.505236 -5.739614  4.229525 -7.752761  4.780244 -4.133152
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.050401 -0.041346  0.017507  0.015062  ...  0.020106 -0.017335
# 1     -1.406621 -6.682186  0.701022 -2.775971  ...  0.384828  0.796939
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.051616 -0.016216  0.004862  0.063981  0.006822  0.001149  0.001962
# 1     -0.023152 -0.039638 -0.065998  0.072576  0.040395  0.176866  0.056315
#
#            Amount
# Class
# 0       89.582366
# 1      118.009607
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling<br>
# Build a sample dataset containing similar distribution of Normal(Legit) Transactions and Fradulent Transactions<br>
#
# Number of Fradulent Transactions --> 382

# %%
legit_sample = legit.sample(n=382)

# %% [markdown]
# Concatenating two DataFrame

# %%
new_credit_dataset = pd.concat([legit_sample, fraud], axis=0) # axis 0 means data added row by row, 1 means data added column wise

# %%
new_credit_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 16870    28253.0 -0.801349 -0.172263  0.802818 -1.186845  0.054183 -1.433403
# 56588    47496.0  1.204795  0.261690  0.274799  1.296995  0.084648  0.036259
# 175084  122192.0 -0.674180 -0.717898  0.991211 -2.642907 -0.881590 -0.292380
# 170076  120003.0  1.904036 -0.625893 -1.692681 -0.575103  1.572159  3.833660
# 6384      7589.0  1.212171  0.179043  0.462518  1.283553 -0.205188 -0.226407
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 16870   0.586922 -0.622241 -1.043208  ...  0.259268  0.917804 -0.140875
# 56588   0.087965 -0.021387  0.233166  ... -0.123626 -0.073715 -0.106508
# 175084 -0.663019  0.238181 -2.030714  ... -0.274132 -0.361004  0.311460
# 170076 -1.584413  1.151526  1.115367  ...  0.184811  0.481712  0.260901
# 6384   -0.239593 -0.064537  1.689250  ... -0.281460 -0.684694 -0.068755
#
#              V24       V25       V26       V27       V28  Amount  Class
# 16870   0.402212 -0.135073 -0.198608 -0.375070 -0.038044   34.99      0
# 56588  -0.250760  0.732549 -0.291555  0.044397  0.012286    1.00      0
# 175084 -0.402136 -0.881843 -0.597869 -0.174773 -0.135604   35.94      0
# 170076  0.627287 -0.554543  0.504453  0.034746 -0.006702   29.99      0
# 6384   -0.571410  0.441366 -0.464120 -0.009184  0.019186   36.00      0
#
# [5 rows x 31 columns]

# %%
new_credit_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 192382  129668.0  0.753356  2.284988 -5.164492  3.831112 -0.073622 -1.316596
# 192529  129741.0 -1.396204  2.618584 -6.036770  3.552454  1.030091 -2.950358
# 192584  129764.0 -2.434004  3.225947 -6.596282  3.593161 -1.079452 -1.739741
# 192687  129808.0  1.522080 -0.519429 -2.581685  0.774741  0.206722 -1.431020
# 195383  131024.0  0.469750 -1.237555 -1.767341  4.833490 -0.268715 -0.512760
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 192382 -1.855495  0.831079 -1.567514  ...  0.382007  0.033958  0.187697
# 192529 -1.528506  0.189319 -1.433554  ...  0.143177 -0.390176  0.356029
# 192584 -0.047420  0.301424 -1.779434  ... -0.035491 -0.419178  0.157436
# 192687  0.757011 -0.444418  0.997921  ...  0.019649 -0.211678 -0.247452
# 195383  1.140149 -0.341273 -1.046351  ...  0.303905 -0.647075 -0.373014
#
#              V24       V25       V26       V27       V28  Amount  Class
# 192382  0.358433 -0.488934 -0.258802  0.296145 -0.047174    2.00      1
# 192529 -0.762352  0.096510 -0.487861  0.062655 -0.240732    1.00      1
# 192584 -0.714849  0.468859 -0.348522  0.420036 -0.327643  362.55      1
# 192687 -0.279472  0.239646 -0.508398 -0.015551  0.041881  276.17      1
# 195383  0.260801 -0.496566 -0.245973 -0.117858  0.144774  723.21      1
#
# [5 rows x 31 columns]

# %%
new_credit_dataset['Class'].value_counts()
# Out:
# Class
# 0    382
# 1    382
# Name: count, dtype: int64

# %%
new_credit_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      69806.871728 -0.065822 -0.016340  0.201752  0.101495 -0.106779
# 1      60726.505236 -5.739614  4.229525 -7.752761  4.780244 -4.133152
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.084384 -0.014093  0.044567  0.034693  ... -0.013142  0.016315
# 1     -1.406621 -6.682186  0.701022 -2.775971  ...  0.384828  0.796939
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.050691 -0.043282  0.039333  0.050784 -0.013868 -0.049679  0.006235
# 1     -0.023152 -0.039638 -0.065998  0.072576  0.040395  0.176866  0.056315
#
#            Amount
# Class
# 0      100.032120
# 1      118.009607
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_credit_dataset.drop(columns='Class', axis=1)
Y = new_credit_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 16870    28253.0 -0.801349 -0.172263  0.802818 -1.186845  0.054183 -1.433403
# 56588    47496.0  1.204795  0.261690  0.274799  1.296995  0.084648  0.036259
# 175084  122192.0 -0.674180 -0.717898  0.991211 -2.642907 -0.881590 -0.292380
# 170076  120003.0  1.904036 -0.625893 -1.692681 -0.575103  1.572159  3.833660
# 6384      7589.0  1.212171  0.179043  0.462518  1.283553 -0.205188 -0.226407
# ...          ...       ...       ...       ...       ...       ...       ...
# 192382  129668.0  0.753356  2.284988 -5.164492  3.831112 -0.073622 -1.316596
# 192529  129741.0 -1.396204  2.618584 -6.036770  3.552454  1.030091 -2.950358
# 192584  129764.0 -2.434004  3.225947 -6.596282  3.593161 -1.079452 -1.739741
# 192687  129808.0  1.522080 -0.519429 -2.581685  0.774741  0.206722 -1.431020
# 195383  131024.0  0.469750 -1.237555 -1.767341  4.833490 -0.268715 -0.512760
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 16870   0.586922 -0.622241 -1.043208  ... -0.185621  0.259268  0.917804
# 56588   0.087965 -0.021387  0.233166  ... -0.158415 -0.123626 -0.073715
# 175084 -0.663019  0.238181 -2.030714  ... -0.404325 -0.274132 -0.361004
# 170076 -1.584413  1.151526  1.115367  ... -0.001498  0.184811  0.481712
# 6384   -0.239593 -0.064537  1.689250  ... -0.178561 -0.281460 -0.684694
# ...          ...       ...       ...  ...       ...       ...       ...
# 192382 -1.855495  0.831079 -1.567514  ...  0.285792  0.382007  0.033958
# 192529 -1.528506  0.189319 -1.433554  ...  0.031795  0.143177 -0.390176
# 192584 -0.047420  0.301424 -1.779434  ... -0.280533 -0.035491 -0.419178
# 192687  0.757011 -0.444418  0.997921  ...  0.361169  0.019649 -0.211678
# 195383  1.140149 -0.341273 -1.046351  ...  1.277315  0.303905 -0.647075
#
#              V23       V24       V25       V26       V27       V28  Amount
# 16870  -0.140875  0.402212 -0.135073 -0.198608 -0.375070 -0.038044   34.99
# 56588  -0.106508 -0.250760  0.732549 -0.291555  0.044397  0.012286    1.00
# 175084  0.311460 -0.402136 -0.881843 -0.597869 -0.174773 -0.135604   35.94
# 170076  0.260901  0.627287 -0.554543  0.504453  0.034746 -0.006702   29.99
# 6384   -0.068755 -0.571410  0.441366 -0.464120 -0.009184  0.019186   36.00
# ...          ...       ...       ...       ...       ...       ...     ...
# 192382  0.187697  0.358433 -0.488934 -0.258802  0.296145 -0.047174    2.00
# 192529  0.356029 -0.762352  0.096510 -0.487861  0.062655 -0.240732    1.00
# 192584  0.157436 -0.714849  0.468859 -0.348522  0.420036 -0.327643  362.55
# 192687 -0.247452 -0.279472  0.239646 -0.508398 -0.015551  0.041881  276.17
# 195383 -0.373014  0.260801 -0.496566 -0.245973 -0.117858  0.144774  723.21
#
# [764 rows x 30 columns]

# %%
print(Y)
# Out:
# 16870     0
# 56588     0
# 175084    0
# 170076    0
# 6384      0
#          ..
# 192382    1
# 192529    1
# 192584    1
# 192687    1
# 195383    1
# Name: Class, Length: 764, dtype: int64

# %% [markdown]
# Spliting the data into Training Data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (764, 30) (611, 30) (153, 30)

# %% [markdown]
# MODEL TRAINING <br>
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# Training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# MODEL EVALUATION<br>
# Accuracy Score

# %%
# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9443535188216039

# %%
# Accuracy on training data
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Testing data : ', testing_data_accuracy)
# Out:
# Accuracy on Testing data :  0.934640522875817
